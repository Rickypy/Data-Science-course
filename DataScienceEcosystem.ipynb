# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# + Mention some popular languages for Data Science
# + Learn about some commonly used libraries by Data Scientists
# + View a simple table to list Tools for Data Science
# + Use Markdown and Code cells
# + Use Code cells to solve arithmetic problems

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. Scala
# 4. Java

# %% [markdown]
# Some of the commonly used libraries by Data Scientists include:
#
# 1. Pandas
# 2. Matplotlib
# 3. NumPy
# 4. Seaborn

# %% [markdown]
#  | Data Science Tools |
#  | ------------------ |
#  | Jupyter Notebook |
#  | R Studio |
#  | GitHub |

# %% [markdown]
# ## Below are a few examples of evaluating arithmetic expressions in Python

# %%
#This is a simple arithmetic expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %%
#This will convert 200 minutes to hours dividing by 60
a = 200
b = 60
H = a/b
print(str(H) + " Hours")
# Out:
# 3.3333333333333335 Hours

# %% [markdown]
# ## Author:
# Ricardo Ramos
